# %% [markdown]
# # ParallelBarnesHut Examples

# %% [markdown]
# ## Install Package

# %%
import Pkg; Pkg.add(Pkg.PackageSpec(url = "https://github.com/alexhad6/ParallelBarnesHut.jl"))
# Out:
#   Updating registry at `~/.julia/registries/General`
#   Updating git-repo `https://github.com/JuliaRegistries/General.git`
#   Updating git-repo `https://github.com/alexhad6/ParallelBarnesHut.jl`
#   Updating git-repo `https://github.com/alexhad6/ParallelBarnesHut.jl`
#  Resolving package versions...
#   Updating `~/.julia/environments/v1.3/Project.toml`
#  [no changes]
#   Updating `~/.julia/environments/v1.3/Manifest.toml`
#  [no changes]

# %% [markdown]
# ## Import Package
# This will precompile, which might take a while since it requires Plots.

# %%
using ParallelBarnesHut
# Out:
# ┌ Info: Precompiling ParallelBarnesHut [e2202fc0-9590-11ea-2e04-3545117ce846]
# └ @ Base loading.jl:1273

# %%
particles = rand_particles(1000)
show_particles(particles)
